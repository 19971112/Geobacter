# %%
#!/usr/bin/env python
import sys
from ete3 import Tree, PhyloTree, SeqMotifFace, TreeStyle

t = PhyloTree("../../analysis/16S_phylogeny_all/rename_16S_all.maf.newick.newick") #newicファイルを引数で指定
t.link_to_alignment("../../analysis/16S_phylogeny_all/rename_16S_all.maf")   # alignment fileをツリーにリンクさせる。
t.render("motifs_align.png", w=20000, dpi=500) # 書き出し。wで幅、hで高さ、unitで単位(“px”: pixels, “mm”: millimeters, “in”: inches)、dpiを指定可能
# Out:
# {'nodes': [[0.44531490400251367,
#    208.7983302476864,
#    6.679723560037705,
#    215.0327389037216,
#    0,
#    None],
#   [32.47825943776122,
#    54.12663497243053,
#    38.71266809379641,
#    60.36104362846572,
#    1,
#    None],
#   [142.23761617903918,
#    26.71889424015082,
#    148.47202483507436,
#    32.95330289618601,
#    2,
#    None],
#   [147.5813994626223,
#    15.140706736085464,
#    153.8158081186575,
#    21.375115392120655,
#    3,
#    None],
#   [152.92517831065246,
#    4.453149040025137,
#    157.3783273506776,
#    8.906298080050274,
#    4,
#    None],
#   [152.92517831065246,
#    16.031336544090493,
#    157.3783273506776,
#    20.484485584115628,
#    5,
#    None],
#   [152.92517831065246,
#    27.609524048155848,
#    157.3783273506776,
#    32.062673088180986,
#    6,
#    None],
#   [147.5813994626223,
#    39.1877115522212,
#    152.03454850264743,
#    43.64086059224634,
#    7,
#    None],
#   [75.83463839936435,
#    81.53437570471024,
# ...
